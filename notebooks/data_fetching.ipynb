# %% [markdown]
# # Data Fetching Playground
# Use this notebook to test Cricbuzz API calls and experiment with pushing data into the SQL database, before wiring logic into the Streamlit pages.

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))
from utils.cricbuzz_api import get_live_matches, get_recent_matches, get_top_batting_stats
from utils.db_connection import run_query, run_action, test_connection

# %%
# 1. Check DB connection
test_connection()

# %%
# 2. Try the live matches endpoint (requires CRICBUZZ_API_KEY in your environment / .env)
data, error = get_live_matches()
print(error)
data

# %%
# 3. Quick sanity query against the sample database
run_query('SELECT * FROM players LIMIT 5')
